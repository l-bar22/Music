# %%
import requests
import datetime
import base64
import os
from dotenv import load_dotenv
load_dotenv()
import json
from urllib.parse import urlencode

# %%
client_id=os.getenv("CLIENT_ID1")
client_secret=os.getenv("CLIENT_SECRET1")

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires= datetime.datetime.now()
    access_token_did_expire =True
    client_id=None
    client_secret=None
    token_url='https://accounts.spotify.com/api/token'
     
    
    def __init__(self,client_id,client_secret,*args,**kwargs):
        #super calls any inherited class in itself
        super().__init__(*args,*kwargs)
        self.client_id=client_id
        self.client_secret=client_secret
        
    def get_client_credentials(self):
        client_id=self.client_id
        client_secret=self.client_secret
        if client_secret == None or client_id == None:
            raise Exception('You must set client_id and client_secret')
        
        client_creds=f'{client_id}:{client_secret}'
        client_creds_b64=base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
        
    def get_token_headers(self):
        client_creds_b64=self.get_client_credentials()
        return  {
    "Authorization":f'Basic {client_creds_b64}'}
    
    def get_token_data(self):
        return {
    "grant_type":'client_credentials'}
    
    def perform_auth(self):
        token_url=self.token_url
        token_data=self.get_token_data()
        token_headers=self.get_token_headers()
        r=requests.post(token_url,data=token_data,headers=token_headers)
        print(r.json())
        if r.status_code  not in range(200,299):
            return False
        data=r.json()
        now=datetime.datetime.now()
        access_token=data['access_token']
        expires_in=data['expires_in']#seconds
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token=access_token
        self.access_token_expires=expires
        self.access_token_did_expire = expires < now
        return True

# %%
spotify=SpotifyAPI(client_id,client_secret)

# %%
#spotify1=spotify.perform_auth()

# %%
access_token=spotify.access_token

# %%
#spotify.search

# %%
headers = {
    'Authorization':f"Bearer {access_token}"
    
}
endpoint = "https://api.spotify.com/v1/search"
data= urlencode({"q":"rewind-The%", "type":"playlist"})
print(data)

lookup_url= f"{endpoint}?{data}"
print(lookup_url)

r= requests.get(lookup_url,headers=headers)

print(r.status_code)
# Out:
# q=rewind-The%25&type=playlist
# https://api.spotify.com/v1/search?q=rewind-The%25&type=playlist
# 200

# %%
playlist_data=r.json()
playlist_data
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=rewind-The%25&type=playlist&offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'Remember what you listened to in 2010? Rewind and rediscover your favorites.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXc6IFF23C9jj'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXc6IFF23C9jj',
#     'id': '37i9dQZF1DXc6IFF23C9jj',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000327ba1078080355421d1a49e2',
#       'width': None}],
#     'name': 'Rewind - The Sound of 2010',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU5NTYwOTgyMSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXc6IFF23C9jj/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXc6IFF23C9jj'},
#    {'collaborative': False,
#     'description': 'Remember what you listened to in 2012? Rewind and rediscover your favorites.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0yEZaMOXna3'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0yEZaMOXna3',
#     'id': '37i9dQZF1DX0yEZaMOXna3',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000035059e51d764b9eff86cbc8ec',
#       'width': None}],
#     'name': 'Rewind - The Sound of 2012',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU5NTYwOTgzMSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0yEZaMOXna3/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX0yEZaMOXna3'},
#    {'collaborative': False,
#     'description': 'Remember what you listened to in 2018? Rewind and rediscover your favorites.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXe2bobNYDtW8'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXe2bobNYDtW8',
#     'id': '37i9dQZF1DXe2bobNYDtW8',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000032996a2205776213536c3df03',
#       'width': None}],
#     'name': 'Rewind - The Sound of 2018',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU5NTYwOTgzMSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXe2bobNYDtW8/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXe2bobNYDtW8'},
#    {'collaborative': False,
#     'description': 'Remember what you listened to in 2011? Rewind and rediscover your favorites.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcagnSNtrGuJ'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcagnSNtrGuJ',
#     'id': '37i9dQZF1DXcagnSNtrGuJ',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000387b53646189f6431b35d9086',
#       'width': None}],
#     'name': 'Rewind - The Sound of 2011',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU5NTYwOTg0MSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcagnSNtrGuJ/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXcagnSNtrGuJ'},
#    {'collaborative': False,
#     'description': 'Remember what you listened to in 2015? Rewind and rediscover your favorites.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX9ukdrXQLJGZ'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9ukdrXQLJGZ',
#     'id': '37i9dQZF1DX9ukdrXQLJGZ',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000033c6203803741db6a7f91042a',
#       'width': None}],
#     'name': 'Rewind - The Sound of 2015',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU5NTYwOTgzNiwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9ukdrXQLJGZ/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX9ukdrXQLJGZ'},
#    {'collaborative': False,
#     'description': 'Remember what you listened to in 2017? Rewind and rediscover your favorites.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTE7dVUebpUW'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTE7dVUebpUW',
#     'id': '37i9dQZF1DWTE7dVUebpUW',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000035cf33a0264a5721d2d21b272',
#       'width': None}],
#     'name': 'Rewind - The Sound of 2017',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU5NTYwOTg3MywwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTE7dVUebpUW/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWTE7dVUebpUW'},
#    {'collaborative': False,
#     'description': 'Remember what you listened to in 2014? Rewind and rediscover your favorites.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0h0QnLkMBl4'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0h0QnLkMBl4',
#     'id': '37i9dQZF1DX0h0QnLkMBl4',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003f941fe8732cca7f1b0089cb7',
#       'width': None}],
#     'name': 'Rewind - The Sound of 2014',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU5NTYwOTgzOCwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0h0QnLkMBl4/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX0h0QnLkMBl4'},
#    {'collaborative': False,
#     'description': 'Remember what you listened to in 2013? Rewind and rediscover your favorites.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX3Sp0P28SIer'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3Sp0P28SIer',
#     'id': '37i9dQZF1DX3Sp0P28SIer',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003626bff32b0a5050062f60c8c',
#       'width': None}],
#     'name': 'Rewind - The Sound of 2013',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU5NTYwOTgyNCwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3Sp0P28SIer/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX3Sp0P28SIer'},
#    {'collaborative': False,
#     'description': 'Remember what you listened to in 2016? Rewind and rediscover your favorites.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX8XZ6AUo9R4R'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8XZ6AUo9R4R',
#     'id': '37i9dQZF1DX8XZ6AUo9R4R',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003614ea5292934297fbab6c869',
#       'width': None}],
#     'name': 'Rewind - The Sound of 2016',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU5NTYwOTgzNywwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8XZ6AUo9R4R/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX8XZ6AUo9R4R'},
#    {'collaborative': False,
#     'description': 'Rewind and rediscover your favorite songs from 2019.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWVRSukIED0e9'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWVRSukIED0e9',
#     'id': '37i9dQZF1DWVRSukIED0e9',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003f949eb6c6d3971a54f6a2f57',
#       'width': None}],
#     'name': 'Rewind - The Sound of 2019',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU5NTYwOTg0OCwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWVRSukIED0e9/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWVRSukIED0e9'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/4wfmadxaRpdBhUKgSyfbei'},
#     'href': 'https://api.spotify.com/v1/playlists/4wfmadxaRpdBhUKgSyfbei',
#     'id': '4wfmadxaRpdBhUKgSyfbei',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b27354c6edd554935d73e159e199ab67616d0000b273ab647295c0c97446c1f1a3b5ab67616d0000b273e13de7b8662b085b0885ffefab67616d0000b273e691217483df8798445c82e2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b27354c6edd554935d73e159e199ab67616d0000b273ab647295c0c97446c1f1a3b5ab67616d0000b273e13de7b8662b085b0885ffefab67616d0000b273e691217483df8798445c82e2',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000

#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273597e2b5abdde10dd7ff73283ab67616d0000b2735c9890c0456a3719eeecd8aaab67616d0000b27373b565ab9d713e8d5586aac2ab67616d0000b273e13de7b8662b085b0885ffef',
#       'width': 60}],
#     'name': 'Rewind the Sound of 2008 & 2009',
#     'owner': {'display_name': 'Cristian Jorge Valverde',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/11162958544'},
#      'href': 'https://api.spotify.com/v1/users/11162958544',
#      'id': '11162958544',
#      'type': 'user',
#      'uri': 'spotify:user:11162958544'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzQ5LDY0NTgyNzdiYjIxMmFjYjQ5NjAyMGZlYjRmN2NlZjA4ZTVhYzJlMjU=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/3TgzbLyAnVQVe77UL0IAsR/tracks',
#      'total': 77},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:3TgzbLyAnVQVe77UL0IAsR'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/4EueLT0sWDRRA7f1VwbT1W'},
#     'href': 'https://api.spotify.com/v1/playlists/4EueLT0sWDRRA7f1VwbT1W',
#     'id': '4EueLT0sWDRRA7f1VwbT1W',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b273006adc0cc250c8f9c5494aecab67616d0000b273a35daeab41d7d6da14cc809cab67616d0000b273de720f487ec5a6a3cfad9ebbab67616d0000b273f049fc9322f0c93646cdcc77',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b273006adc0cc250c8f9c5494aecab67616d0000b273a35daeab41d7d6da14cc809cab67616d0000b273de720f487ec5a6a3cfad9ebbab67616d0000b273f049fc9322f0c93646cdcc77',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273006adc0cc250c8f9c5494aecab67616d0000b273a35daeab41d7d6da14cc809cab67616d0000b273de720f487ec5a6a3cfad9ebbab67616d0000b273f049fc9322f0c93646cdcc77',
#       'width': 60}],
#     'name': 'Rewind - The Sound of 2005',
#     'owner': {'display_name': 'philippeceasar',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/philippeceasar'},
#      'href': 'https://api.spotify.com/v1/users/philippeceasar',
#      'id': 'philippeceasar',
#      'type': 'user',
#      'uri': 'spotify:user:philippeceasar'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzIzLDg4NzBlZjY5MzQ5NWRlMDBkYmFjNGExYTZlMmI5NTI3MjcwZGYyZTc=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/4EueLT0sWDRRA7f1VwbT1W/tracks',
#      'total': 251},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:4EueLT0sWDRRA7f1VwbT1W'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/4Rp405wgig1eupt0FskaPT'},
#     'href': 'https://api.spotify.com/v1/playlists/4Rp405wgig1eupt0FskaPT',
#     'id': '4Rp405wgig1eupt0FskaPT',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b273365b3fb800c19f7ff72602daab67616d0000b27344d34793d0f4bddf28e0e8a8ab67616d0000b27356ff19308ebeb48e2ba6094bab67616d0000b27392f2d790c6a97b195f66d51e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b273365b3fb800c19f7ff72602daab67616d0000b27344d34793d0f4bddf28e0e8a8ab67616d0000b27356ff19308ebeb48e2ba6094bab67616d0000b27392f2d790c6a97b195f66d51e',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273365b3fb800c19f7ff72602daab67616d0000b27344d34793d0f4bddf28e0e8a8ab67616d0000b27356ff19308ebeb48e2ba6094bab67616d0000b27392f2d790c6a97b195f66d51e',
#       'width': 60}],
#     'name': 'Rewind - The Sound of 2004',
#     'owner': {'display_name': 'hellokittygirl818',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/musnuggets'},
#      'href': 'https://api.spotify.com/v1/users/musnuggets',
#      'id': 'musnuggets',
#      'type': 'user',
#      'uri': 'spotify:user:musnuggets'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NjMsNDE2OWQyOTE1NDg0ZWQ5MTYxYjVkNWQ1ZmVhOThhZDU3N2I0Yjk4NQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/4Rp405wgig1eupt0FskaPT/tracks',
#      'total': 60},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:4Rp405wgig1eupt0FskaPT'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/6Kq78BO6aWgemrNsyFHFAc'},
#     'href': 'https://api.spotify.com/v1/playlists/6Kq78BO6aWgemrNsyFHFAc',
#     'id': '6Kq78BO6aWgemrNsyFHFAc',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b27338802659d156935ada63c9e3ab67616d0000b2735675e83f707f1d7271e5cf8aab67616d0000b2738583df1a14bea9175f9ac520ab67616d0000b273b8c0135a218de2d10a8435f5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b27338802659d156935ada63c9e3ab67616d0000b2735675e83f707f1d7271e5cf8aab67616d0000b2738583df1a14bea9175f9ac520ab67616d0000b273b8c0135a218de2d10a8435f5',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b27338802659d156935ada63c9e3ab67616d0000b2735675e83f707f1d7271e5cf8aab67616d0000b2738583df1a14bea9175f9ac520ab67616d0000b273b8c0135a218de2d10a8435f5',
#       'width': 60}],
#     'name': 'Rewind- The sound of 2020',
#     'owner': {'display_name': 'Ersin Teke',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/1234740691'},
#      'href': 'https://api.spotify.com/v1/users/1234740691',
#      'id': '1234740691',
#      'type': 'user',
#      'uri': 'spotify:user:1234740691'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzcsNWY4YjRkOTI1YTk2NTkyYTM1N2IzOWUxMDVlZjE1MGQ2ODE2MmQyOQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/6Kq78BO6aWgemrNsyFHFAc/tracks',
#      'total': 30},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6Kq78BO6aWgemrNsyFHFAc'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/53TaUjs2q0Vp9GAeEZe9eC'},
#     'href': 'https://api.spotify.com/v1/playlists/53TaUjs2q0Vp9GAeEZe9eC',
#     'id': '53TaUjs2q0Vp9GAeEZe9eC',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706c0000bebb792dc57cd8ce9511a4bab2d9',
#       'width': None}],
#     'name': 'Rewind - The Sound of 2013-2016',
#     'owner': {'display_name': 'Neo Ryan',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/ryrybn'},
#      'href': 'https://api.spotify.com/v1/users/ryrybn',
#      'id': 'ryrybn',
#      'type': 'user',
#      'uri': 'spotify:user:ryrybn'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'Niw3YWExYWNlMmI3YWFmNzlhODkwMmI0NjYxMTY2YzI1ZmExYjdkNDA2',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/53TaUjs2q0Vp9GAeEZe9eC/tracks',
#      'total': 237},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:53TaUjs2q0Vp9GAeEZe9eC'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=rewind-The%25&type=playlist&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 900}}

# %%
ids = [item["id"] for item in playlist_data["playlists"]["items"]]
ids
# Out:
# ['37i9dQZF1DXc6IFF23C9jj',
#  '37i9dQZF1DX0yEZaMOXna3',
#  '37i9dQZF1DXe2bobNYDtW8',
#  '37i9dQZF1DXcagnSNtrGuJ',
#  '37i9dQZF1DX9ukdrXQLJGZ',
#  '37i9dQZF1DWTE7dVUebpUW',
#  '37i9dQZF1DX0h0QnLkMBl4',
#  '37i9dQZF1DX3Sp0P28SIer',
#  '37i9dQZF1DX8XZ6AUo9R4R',
#  '37i9dQZF1DWVRSukIED0e9',
#  '4wfmadxaRpdBhUKgSyfbei',
#  '0asI3DIK4VSY9xnAzTM31d',
#  '3JTJTR2UUPSJgmRdmFPM0v',
#  '2aRcrgxqqQu0h8aJfHXhOU',
#  '77KjN5z7egRCeVhFtNkNTN',
#  '3TgzbLyAnVQVe77UL0IAsR',
#  '4EueLT0sWDRRA7f1VwbT1W',
#  '4Rp405wgig1eupt0FskaPT',
#  '6Kq78BO6aWgemrNsyFHFAc',
#  '53TaUjs2q0Vp9GAeEZe9eC']

# %%
#res_dict = {'id':items['id'] for items in playlist_data['playlists']['items']}
