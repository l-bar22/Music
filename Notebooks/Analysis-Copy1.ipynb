# %%
import pandas as pd
import numpy as np
import researchpy as rp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
spotify_songs=pd.read_csv('../INPUT/spotify_songs.csv')
spotify_songs.shape
# Out:
# (18454, 25)

# %%
spotify_songs.head().style.highlight_max(color='yellow').highlight_min(color='lightblue')
# Out:
# <style  type="text/css" >
#     #T_355f4a84_d283_11ea_a97d_5b228769f423row0_col14 {
#             : ;
#             background-color:  lightblue;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row0_col15 {
#             : ;
#             background-color:  lightblue;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row0_col16 {
#             background-color:  yellow;
#             : ;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row0_col17 {
#             : ;
#             background-color:  lightblue;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row0_col19 {
#             background-color:  yellow;
#             : ;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row0_col22 {
#             : ;
#             background-color:  lightblue;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row1_col12 {
#             : ;
#             background-color:  lightblue;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row1_col14 {
#             background-color:  yellow;
#             : ;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row1_col16 {
#             background-color:  yellow;
#             : ;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row1_col22 {
#             background-color:  yellow;
#             : ;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row1_col23 {
#             background-color:  yellow;
#             : ;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row2_col4 {
#             : ;
#             background-color:  lightblue;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row2_col12 {
#             background-color:  yellow;
#             : ;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row2_col16 {
#             : ;
#             background-color:  lightblue;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row2_col17 {
#             background-color:  yellow;
#             : ;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row2_col18 {
#             : ;
#             background-color:  lightblue;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row2_col20 {
#             background-color:  yellow;
#             : ;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row2_col21 {
#             background-color:  yellow;
#             : ;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row3_col13 {
#             : ;
#             background-color:  lightblue;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row3_col16 {
#             : ;
#             background-color:  lightblue;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row3_col18 {
#             background-color:  yellow;
#             : ;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row3_col19 {
#             : ;
#             background-color:  lightblue;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row3_col20 {
#             : ;
#             background-color:  lightblue;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row4_col4 {
#             background-color:  yellow;
#             : ;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row4_col13 {
#             background-color:  yellow;
#             : ;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row4_col14 {
#             background-color:  yellow;
#             : ;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row4_col15 {
#             background-color:  yellow;
#             : ;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row4_col16 {
#             background-color:  yellow;
#             : ;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row4_col19 {
#             : ;
#             background-color:  lightblue;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row4_col21 {
#             : ;
#             background-color:  lightblue;
#         }    #T_355f4a84_d283_11ea_a97d_5b228769f423row4_col23 {
#             : ;
#             background-color:  lightblue;
#         }</style><table id="T_355f4a84_d283_11ea_a97d_5b228769f423" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >track_id</th>        <th class="col_heading level0 col1" >track_name</th>        <th class="col_heading level0 col2" >track_artist</th>        <th class="col_heading level0 col3" >lyrics</th>        <th class="col_heading level0 col4" >track_popularity</th>        <th class="col_heading level0 col5" >track_album_id</th>        <th class="col_heading level0 col6" >track_album_name</th>        <th class="col_heading level0 col7" >track_album_release_date</th>        <th class="col_heading level0 col8" >playlist_name</th>        <th class="col_heading level0 col9" >playlist_id</th>        <th class="col_heading level0 col10" >playlist_genre</th>        <th class="col_heading level0 col11" >playlist_subgenre</th>        <th class="col_heading level0 col12" >danceability</th>        <th class="col_heading level0 col13" >energy</th>        <th class="col_heading level0 col14" >key</th>        <th class="col_heading level0 col15" >loudness</th>        <th class="col_heading level0 col16" >mode</th>        <th class="col_heading level0 col17" >speechiness</th>        <th class="col_heading level0 col18" >acousticness</th>        <th class="col_heading level0 col19" >instrumentalness</th>        <th class="col_heading level0 col20" >liveness</th>        <th class="col_heading level0 col21" >valence</th>        <th class="col_heading level0 col22" >tempo</th>        <th class="col_heading level0 col23" >duration_ms</th>        <th class="col_heading level0 col24" >language</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_355f4a84_d283_11ea_a97d_5b228769f423level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_355f4a84_d283_11ea_a97d_5b228769f423row0_col0" class="data row0 col0" >0017A6SJgTbfQVU2EtsPNo</td>
#                         <td id="T_355f4a84_d283_11ea_a97d_5b228769f423row0_col1" class="data row0 col1" >Pangarap</td>
#                         <td id="T_355f4a84_d283_11ea_a97d_5b228769f423row0_col2" class="data row0 col2" >Barbie's Cradle</td>
#                         <td id="T_355f4a84_d283_11ea_a97d_5b228769f423row0_col3" class="data row0 col3" >Minsan pa Nang ako'y napalingon Hindi ko alam Na ika'y tutugon Sa mga tanong na aking nabitawan Hindi ko alam kung ito'y totoo Pangarap ka Sa bawat sandali Langit man ang tingin ko Sayo sana'y marating Hanggang dito na lang yata Ang kaya kong gawin Mangarap na lang At bumulong sa hangin Kailan kaya Darating ulit ang isang Sandali Na ako'y lilingon muli Pangarap ka o tinig mong kay lamig Ang iyong mga ngiti na sa akin ay Nakapagbigay pansin (Ikaw ba ay isang pangarap lang) Pangarap ka o tinig mong kay lamig Ang iyong mga ngiti Na sa akin ay Nakapagbigay... Pangarap ka o tinig mong kay lamig Ang iyong mga ngiti Na sa akin ay Nakapagbigay Pangarap ka o tinig mong kay lamig Ang iyong mga ngiti Na sa akin ay Nakapagbigay pansin</td>
#                         <td id="T_355f4a84_d283_11ea_a97d_5b228769f423row0_col4" class="data row0 col4" >41</td>
#                         <td id="T_355f4a84_d283_11ea_a97d_5b228769f423row0_col5" class="data row0 col5" >1srJQ0njEQgd8w4XSqI4JQ</td>
#                         <td id="T_355f4a84_d283_11ea_a97d_5b228769f423row0_col6" class="data row0 col6" >Trip</td>
#                         <td id="T_355f4a84_d283_11ea_a97d_5b228769f423row0_col7" class="data row0 col7" >2001-01-01</td>
#                         <td id="T_355f4a84_d283_11ea_a97d_5b228769f423row0_col8" class="data row0 col8" >Pinoy Classic Rock</td>
#                         <td id="T_355f4a84_d283_11ea_a97d_5b228769f423row0_col9" class="data row0 col9" >37i9dQZF1DWYDQ8wBxd7xt</td>
#                         <td id="T_355f4a84_d283_11ea_a97d_5b228769f423row0_col10" class="data row0 col10" >rock</td>
#                         <td id="T_355f4a84_d283_11ea_a97d_5b228769f423row0_col11" class="data row0 col11" >classic rock</td>
#                         <td id="T_355f4a84_d283_11ea_a97d_5b228769f423row0_col12" class="data row0 col12" >0.682000</td>
#                         <td id="T_355f4a84_d283_11ea_a97d_5b228

# %%
spotify_songs.info()
spotify_songs.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18454 entries, 0 to 18453
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  18454 non-null  object
#  1   track_name                18454 non-null  object
#  2   track_artist              18454 non-null  object
#  3   lyrics                    18194 non-null  object
#  4   track_popularity          18454 non-null  int64
#  5   track_album_id            18454 non-null  object
#  6   track_album_name          18454 non-null  object
#  7   track_album_release_date  18454 non-null  object
#  8   playlist_name             18454 non-null  object
#  9   playlist_id               18454 non-null  object
#  10  playlist_genre            18454 non-null  object
#  11  playlist_subgenre         18454 non-null  object
#  12  danceability              18454 non-null  float64
#  13  energy                    18454 non-null  float64
#  14  key                       18454 non-null  int64
#  15  loudness                  18454 non-null  float64
#  16  mode                      18454 non-null  int64
#  17  speechiness               18454 non-null  float64
#  18  acousticness              18454 non-null  float64
#  19  instrumentalness          18454 non-null  float64
#  20  liveness                  18454 non-null  float64
#  21  valence                   18454 non-null  float64
#  22  tempo                     18454 non-null  float64
#  23  duration_ms               18454 non-null  int64
#  24  language                  18194 non-null  object
# dtypes: float64(9), int64(4), object(12)
# memory usage: 3.5+ MB
# Index(['track_id', 'track_name', 'track_artist', 'lyrics', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'language'],
#       dtype='object')

# %%
spotify_songs['playlist_genre'].value_counts()
# Out:
# pop      3993
# rock     3521
# rap      3391
# r&b      3326
# latin    2178
# edm      2045
# Name: playlist_genre, dtype: int64

# %%
spotify_songs['playlist_genre'].replace({'pop':-2,'rock':-1,'rap':-0,'r&b':0,'latin':1,'edm':2},inplace=True)

# %%
spotify_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18454 entries, 0 to 18453
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  18454 non-null  object
#  1   track_name                18454 non-null  object
#  2   track_artist              18454 non-null  object
#  3   lyrics                    18194 non-null  object
#  4   track_popularity          18454 non-null  int64
#  5   track_album_id            18454 non-null  object
#  6   track_album_name          18454 non-null  object
#  7   track_album_release_date  18454 non-null  object
#  8   playlist_name             18454 non-null  object
#  9   playlist_id               18454 non-null  object
#  10  playlist_genre            18454 non-null  int64
#  11  playlist_subgenre         18454 non-null  object
#  12  danceability              18454 non-null  float64
#  13  energy                    18454 non-null  float64
#  14  key                       18454 non-null  int64
#  15  loudness                  18454 non-null  float64
#  16  mode                      18454 non-null  int64
#  17  speechiness               18454 non-null  float64
#  18  acousticness              18454 non-null  float64
#  19  instrumentalness          18454 non-null  float64
#  20  liveness                  18454 non-null  float64
#  21  valence                   18454 non-null  float64
#  22  tempo                     18454 non-null  float64
#  23  duration_ms               18454 non-null  int64
#  24  language                  18194 non-null  object
# dtypes: float64(9), int64(5), object(11)
# memory usage: 3.5+ MB

# %%
#spotify_songs['playlist_genre'] = pd.to_numeric(spotify_songs['playlist_genre'])

# %%
spotify_songs.rename(columns={'playlist_genre': 'intervals'}, inplace=True)

# %%
spotify_songs['playlist_subgenre'].value_counts()
# Out:
# indie poptimism              1288
# southern hip hop             1158
# neo soul                     1001
# electropop                    964
# urban contemporary            936
# hard rock                     926
# classic rock                  924
# post-teen pop                 891
# new jack swing                881
# gangster rap                  865
# dance pop                     850
# permanent wave                843
# album rock                    828
# hip hop                       689
# trap                          679
# latin hip hop                 673
# progressive electro house     652
# latin pop                     594
# pop edm                       575
# hip pop                       508
# electro house                 484
# tropical                      473
# reggaeton                     438
# big room                      334
# Name: playlist_subgenre, dtype: int64

# %%
spotify_songs.drop(columns=['lyrics','track_popularity','track_album_id','track_album_name','track_album_release_date','playlist_name','playlist_id','playlist_subgenre','language'],inplace=True)

# %%
spotify_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18454 entries, 0 to 18453
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          18454 non-null  object
#  1   track_name        18454 non-null  object
#  2   track_artist      18454 non-null  object
#  3   intervals         18454 non-null  int64
#  4   danceability      18454 non-null  float64
#  5   energy            18454 non-null  float64
#  6   key               18454 non-null  int64
#  7   loudness          18454 non-null  float64
#  8   mode              18454 non-null  int64
#  9   speechiness       18454 non-null  float64
#  10  acousticness      18454 non-null  float64
#  11  instrumentalness  18454 non-null  float64
#  12  liveness          18454 non-null  float64
#  13  valence           18454 non-null  float64
#  14  tempo             18454 non-null  float64
#  15  duration_ms       18454 non-null  int64
# dtypes: float64(9), int64(4), object(3)
# memory usage: 2.3+ MB

# %%
spotify_songs.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18449    False
# 18450    False
# 18451    False
# 18452    False
# 18453    False
# Length: 18454, dtype: bool

# %%
spotify_songs.describe().style.highlight_min(color='lightblue')
# Out:
# <style  type="text/css" >
#     #T_355f4a85_d283_11ea_a97d_5b228769f423row0_col12 {
#             background-color:  lightblue;
#         }    #T_355f4a85_d283_11ea_a97d_5b228769f423row2_col11 {
#             background-color:  lightblue;
#         }    #T_355f4a85_d283_11ea_a97d_5b228769f423row3_col0 {
#             background-color:  lightblue;
#         }    #T_355f4a85_d283_11ea_a97d_5b228769f423row3_col1 {
#             background-color:  lightblue;
#         }    #T_355f4a85_d283_11ea_a97d_5b228769f423row3_col2 {
#             background-color:  lightblue;
#         }    #T_355f4a85_d283_11ea_a97d_5b228769f423row3_col3 {
#             background-color:  lightblue;
#         }    #T_355f4a85_d283_11ea_a97d_5b228769f423row3_col4 {
#             background-color:  lightblue;
#         }    #T_355f4a85_d283_11ea_a97d_5b228769f423row3_col5 {
#             background-color:  lightblue;
#         }    #T_355f4a85_d283_11ea_a97d_5b228769f423row3_col6 {
#             background-color:  lightblue;
#         }    #T_355f4a85_d283_11ea_a97d_5b228769f423row3_col7 {
#             background-color:  lightblue;
#         }    #T_355f4a85_d283_11ea_a97d_5b228769f423row3_col8 {
#             background-color:  lightblue;
#         }    #T_355f4a85_d283_11ea_a97d_5b228769f423row3_col9 {
#             background-color:  lightblue;
#         }    #T_355f4a85_d283_11ea_a97d_5b228769f423row3_col10 {
#             background-color:  lightblue;
#         }    #T_355f4a85_d283_11ea_a97d_5b228769f423row4_col5 {
#             background-color:  lightblue;
#         }    #T_355f4a85_d283_11ea_a97d_5b228769f423row4_col8 {
#             background-color:  lightblue;
#         }</style><table id="T_355f4a85_d283_11ea_a97d_5b228769f423" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >intervals</th>        <th class="col_heading level0 col1" >danceability</th>        <th class="col_heading level0 col2" >energy</th>        <th class="col_heading level0 col3" >key</th>        <th class="col_heading level0 col4" >loudness</th>        <th class="col_heading level0 col5" >mode</th>        <th class="col_heading level0 col6" >speechiness</th>        <th class="col_heading level0 col7" >acousticness</th>        <th class="col_heading level0 col8" >instrumentalness</th>        <th class="col_heading level0 col9" >liveness</th>        <th class="col_heading level0 col10" >valence</th>        <th class="col_heading level0 col11" >tempo</th>        <th class="col_heading level0 col12" >duration_ms</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_355f4a85_d283_11ea_a97d_5b228769f423level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row0_col0" class="data row0 col0" >18454.000000</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row0_col1" class="data row0 col1" >18454.000000</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row0_col2" class="data row0 col2" >18454.000000</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row0_col3" class="data row0 col3" >18454.000000</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row0_col4" class="data row0 col4" >18454.000000</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row0_col5" class="data row0 col5" >18454.000000</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row0_col6" class="data row0 col6" >18454.000000</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row0_col7" class="data row0 col7" >18454.000000</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row0_col8" class="data row0 col8" >18454.000000</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row0_col9" class="data row0 col9" >18454.000000</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row0_col10" class="data row0 col10" >18454.000000</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row0_col11" class="data row0 col11" >18454.000000</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row0_col12" class="data row0 col12" >18454.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_355f4a85_d283_11ea_a97d_5b228769f423level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row1_col0" class="data row1 col0" >-0.283895</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row1_col1" class="data row1 col1" >0.644066</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row1_col2" class="data row1 col2" >0.692289</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row1_col3" class="data row1 col3" >5.342094</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row1_col4" class="data row1 col4" >-6.769159</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row1_col5" class="data row1 col5" >0.580525</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row1_col6" class="data row1 col6" >0.106192</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row1_col7" class="data row1 col7" >0.175348</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row1_col8" class="data row1 col8" >0.051216</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row1_col9" class="data row1 col9" >0.189593</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row1_col10" class="data row1 col10" >0.520598</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row1_col11" class="data row1 col11" >120.812167</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row1_col12" class="data row1 col12" >230319.306763</td>
#             </tr>
#             <tr>
#                         <th id="T_355f4a85_d283_11ea_a97d_5b228769f423level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row2_col0" class="data row2 col0" >1.239789</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row2_col1" class="data row2 col1" >0.150071</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row2_col2" class="data row2 col2" >0.180635</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row2_col3" class="data row2 col3" >3.613121</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row2_col4" class="data row2 col4" >2.920757</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row2_col5" class="data row2 col5" >0.493487</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row2_col6" class="data row2 col6" >0.102291</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row2_col7" class="data row2 col7" >0.217795</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row2_col8" class="data row2 col8" >0.168263</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row2_col9" class="data row2 col9" >0.153751</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row2_col10" class="data row2 col10" >0.228716</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row2_col11" class="data row2 col11" >27.586424</td>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row2_col12" class="data row2 col12" >57255.086685</td>
#             </tr>
#             <tr>
#                         <th id="T_355f4a85_d283_11ea_a97d_5b228769f423level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_355f4a85_d283_11ea_a97d_5b228769f423row3_col0" class="data row3 col0" >-2.000000</td>

# %%
#Correlation between danceability and energy
sns_plot=sns.scatterplot(x="danceability", y="energy", data=spotify_songs,palette='Blues')
sns_plot.figure.savefig('../OUTPUT/out2.png')

# %%
#Instrumentalness and speechiness
sns_plot1=sns.scatterplot(x="instrumentalness", y="speechiness", data=spotify_songs,palette='Blues')
sns_plot1.figure.savefig('../OUTPUT/out3.png')

# %%
#Loudness and Valence
sns_plot2=sns.scatterplot(x="loudness", y="valence", data=spotify_songs)
sns_plot2.figure.savefig('../OUTPUT/out4.png')

# %%
spotify_songs.corr()
# Out:
#                   intervals  danceability    energy       key  loudness  \
# intervals          1.000000      0.185500  0.070765  0.013334  0.114416
# danceability       0.185500      1.000000 -0.089708  0.002090  0.022830
# energy             0.070765     -0.089708  1.000000  0.018833  0.674795
# key                0.013334      0.002090  0.018833  1.000000  0.007280
# loudness           0.114416      0.022830  0.674795  0.007280  1.000000
# mode              -0.084822     -0.078020 -0.009903 -0.169589 -0.035276
# speechiness        0.143093      0.204041 -0.011986  0.026282  0.029858
# acousticness      -0.032468     -0.029240 -0.546033 -0.002067 -0.370628
# instrumentalness   0.067016     -0.049187  0.042093  0.004243 -0.099164
# liveness           0.038531     -0.114719  0.156931  0.000682  0.071159
# valence           -0.042131      0.343419  0.207941  0.021927  0.050211
# tempo             -0.002977     -0.201465  0.138291 -0.018967  0.082558
# duration_ms       -0.020498     -0.133803 -0.021134  0.016984 -0.159026
#
#                       mode  speechiness  acousticness  instrumentalness  \
# intervals        -0.084822     0.143093     -0.032468          0.067016
# danceability     -0.078020     0.204041     -0.029240         -0.049187
# energy           -0.009903    -0.011986     -0.546033          0.042093
# key              -0.169589     0.026282     -0.002067          0.004243
# loudness         -0.035276     0.029858     -0.370628         -0.099164
# mode              1.000000    -0.070013      0.022191         -0.002906
# speechiness      -0.070013     1.000000     -0.000217         -0.108365
# acousticness      0.022191    -0.000217      1.000000         -0.015803
# instrumentalness -0.002906    -0.108365     -0.015803          1.000000
# liveness          0.004850     0.060072     -0.067491         -0.000021
# valence          -0.009382     0.035202     -0.069817         -0.103020
# tempo             0.026421     0.033620     -0.096149          0.028126
# duration_ms       0.012433    -0.094343     -0.052996          0.078505
#
#                   liveness   valence     tempo  duration_ms
# intervals         0.038531 -0.042131 -0.002977    -0.020498
# danceability     -0.114719  0.343419 -0.201465    -0.133803
# energy            0.156931  0.207941  0.138291    -0.021134
# key               0.000682  0.021927 -0.018967     0.016984
# loudness          0.071159  0.050211  0.082558    -0.159026
# mode              0.004850 -0.009382  0.026421     0.012433
# speechiness       0.060072  0.035202  0.033620    -0.094343
# acousticness     -0.067491 -0.069817 -0.096149    -0.052996
# instrumentalness -0.000021 -0.103020  0.028126     0.078505
# liveness          1.000000 -0.006931  0.015658     0.026988
# valence          -0.006931  1.000000 -0.017101    -0.045546
# tempo             0.015658 -0.017101  1.000000    -0.014873
# duration_ms       0.026988 -0.045546 -0.014873     1.000000

# %%
fig = plt.figure(figsize=(15, 10))
sns.heatmap(spotify_songs.corr(),  annot=True)
plt.title('Correlation of every features', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation of every features')

# %%
#spotify_songs.plot(kind='bar',figsize=(40,40))

# %%
spotify_songs.to_csv('../OUTPUT/spotify.csv')

# %%
playlist=pd.read_csv('../OUTPUT/playlist.csv')
playlist.head()
# Out:
#    Unnamed: 0     artist            track_name                track_id  \
# 0           0     Eminem  Love The Way You Lie  15JINEqzVMv3SvJTAXAKED
# 1           1      Kesha               TiK ToK  0HPD5WQqrq7wPWR7P7Dw1i
# 2           2  Lady Gaga           Bad Romance  0SiywuOBRcynK0uKGWdCnn
# 3           3      Train      Hey, Soul Sister  4HlFJV71xXKIGcU3kRyttv
# 4           4      Robyn     Dancing On My Own  5vd5Xnm203ZmzulaK49zJw
#
#    danceability  energy  key  loudness  mode  speechiness  instrumentalness  \
# 0         0.749   0.925   10    -5.034     1       0.2270          0.000000
# 1         0.755   0.837    2    -2.718     0       0.1420          0.000000
# 2         0.696   0.921    0    -3.755     1       0.0363          0.000052
# 3         0.673   0.886    1    -4.440     0       0.0431          0.000000
# 4         0.687   0.865    6    -4.663     1       0.0349          0.225000
#
#    liveness  valence    tempo  duration_ms
# 0    0.5200    0.641   86.989       263373
# 1    0.2890    0.714  120.028       199693
# 2    0.0842    0.714  119.001       294573
# 3    0.0826    0.795   97.012       216773
# 4    0.0966    0.261  117.015       288670

# %%
playlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        950 non-null    int64
#  1   artist            950 non-null    object
#  2   track_name        950 non-null    object
#  3   track_id          950 non-null    object
#  4   danceability      950 non-null    float64
#  5   energy            950 non-null    float64
#  6   key               950 non-null    int64
#  7   loudness          950 non-null    float64
#  8   mode              950 non-null    int64
#  9   speechiness       950 non-null    float64
#  10  instrumentalness  950 non-null    float64
#  11  liveness          950 non-null    float64
#  12  valence           950 non-null    float64
#  13  tempo             950 non-null    float64
#  14  duration_ms       950 non-null    int64
# dtypes: float64(8), int64(4), object(3)
# memory usage: 111.5+ KB

# %%
playlist.columns
# Out:
# Index(['Unnamed: 0', 'artist', 'track_name', 'track_id', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms'],
#       dtype='object')

# %%
playlist.drop(columns=['Unnamed: 0'],inplace=True)

# %%
playlist.rename(columns={'artist': 'track_artist'}, inplace=True)
playlist.columns
# Out:
# Index(['track_artist', 'track_name', 'track_id', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms'],
#       dtype='object')

# %%
playlist.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Length: 950, dtype: bool

# %%
playlist=playlist[['track_id','track_name','track_artist','danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'duration_ms']]

# %%
playlist.head()
# Out:
#                  track_id            track_name track_artist  danceability  \
# 0  15JINEqzVMv3SvJTAXAKED  Love The Way You Lie       Eminem         0.749
# 1  0HPD5WQqrq7wPWR7P7Dw1i               TiK ToK        Kesha         0.755
# 2  0SiywuOBRcynK0uKGWdCnn           Bad Romance    Lady Gaga         0.696
# 3  4HlFJV71xXKIGcU3kRyttv      Hey, Soul Sister        Train         0.673
# 4  5vd5Xnm203ZmzulaK49zJw     Dancing On My Own        Robyn         0.687
#
#    energy  key  loudness  mode  speechiness  instrumentalness  liveness  \
# 0   0.925   10    -5.034     1       0.2270          0.000000    0.5200
# 1   0.837    2    -2.718     0       0.1420          0.000000    0.2890
# 2   0.921    0    -3.755     1       0.0363          0.000052    0.0842
# 3   0.886    1    -4.440     0       0.0431          0.000000    0.0826
# 4   0.865    6    -4.663     1       0.0349          0.225000    0.0966
#
#    valence    tempo  duration_ms
# 0    0.641   86.989       263373
# 1    0.714  120.028       199693
# 2    0.714  119.001       294573
# 3    0.795   97.012       216773
# 4    0.261  117.015       288670

# %%
#spotify.to_csv('../OUTPUT/spotify_song.csv')

# %%
'''spotify1=spotify[['danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'duration_ms']]'''
# Out:
# "spotify1=spotify[['danceability', 'energy',\n       'key', 'loudness', 'mode', 'speechiness', 'instrumentalness',\n       'liveness', 'valence', 'tempo', 'duration_ms']]"

# %%
#spotify1.corr()
